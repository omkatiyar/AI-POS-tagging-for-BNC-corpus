# %% [markdown]
# # PLease this time, before Anyone make any changes, please let me know,
# # Since Mam Has given us one more chance, I don't want to miss it
# # thanks

# %% [markdown]
# ## Import Statements

# %%
# used to parse the files
import xml.etree.ElementTree as xmltree

# for searching the folders
from os.path import isdir
from os.path import isfile
from os import mkdir
from os import listdir

# %% [markdown]
# # File Processing Functions

# %%
# this will directly dump the word_tag pairs from give file in the their corresponding word_tag files
# in sentence format

# so the format is 
# every line of dest file will be a sentence
# we will only consider word tags this time.
# and sentences will be stored as word_tag pairs

def parseFile_mk(source,dest) :
    
    # xmlfile is the file to be handled
    xmlfile = open (source, "r",encoding= "utf-8")
    # we get the text into a variable
    xmlfiletext = xmlfile.read();
    #close xmlfile
    xmlfile.close()
    
    # make am xml tree from that text
    tree = xmltree.fromstring(xmlfiletext)
    
    # make list of sentences
    slist = tree.iter('s')
    
    #open dest file with **overwriting** mode
    dfile = open (dest[:-4]+"_sentence.txt", "w+", encoding = "utf-8")
    
    
    # put the data in the sfile
    for sentence in slist :
        # declare a line variable to store the sentence
        line = ""
        # iterate over every variable in sentence
        for elem in sentence :
            #make sure we only process words for a sentence
            if elem.tag != 'w' :
                continue 
            # fetch pos tag of this elem
            pos = elem.get('c5')
            # if the child doesnot contains c5 then it is of no use for us
            if pos is None :
                continue
                
            # upper case all pos tags    
            pos = pos.upper()   
            
            # some where the authors were confused and they assigned two tags
            # in such scenarios we are deciding to go with first tag and ignore the second
#             pos = pos[:3]
            
            # if I am here it  means pos has c5 tag available so we need to find the text of it.
            txt = elem.text
            if txt is None : 
                continue
            txt = txt.strip()
            # append in the sentence this word
            line =   line +      txt + "_"+ pos        +" "  # extra space added between terms 
                                                             # to just make more clear
        # for word loop finshes
        # write the sentence to the file
        dfile.write(line+"\n")	
    # for sentence loop finished 
    #close file
    dfile.close()

# %%
# function
# this will fetch all the files and generate corresponding files
# this takes source folder and 
def makeSentences_mk(source, dest) :

    #check if the source is a file
    if isfile(source):
        # if yes, then process the file 
        # if destination is not there , the function will create it, and if it is there, it will overrite it.
        parseFile_mk(source,dest)
    else:
        # so the source is a folder, we need to make corresponding folder in the dest 
        #check if dest has the folder
        if not isdir(dest):
            mkdir(dest)
        
        # now enumerate all the items in the source directory    
        for item in listdir(source):
            makeSentences_mk(source+'/'+item,dest+'/'+item)

# %% [markdown]
# # Please Uncomment & Run below Cell to Process Files,
# ## I do processed my files so I have commented this to avoid repeats

# %%
# this segment is used to make the files process all togethor in their own files

source = "given_data"
dest = "processed_data"
makeSentences_mk(source, dest)

# %% [markdown]
# # Combine Function to Combine all the files

# %%
# Collector function, this will dump all sentences into the destination file
def dump_mk(source,dest):

    sfile = open(source, "r", encoding= "utf-8")
    dfile = open(dest, "a", encoding= "utf-8")

    # read entire sfile line by line, yes this is the key
    # Possible Error Point : in our Previous Implementation I was reading It all at same time, this was problem ,
        # whole file became a single sentence
    # and then dump that  into the dfile as itis.
    for line in sfile :
        dfile.write(line + "\n")

    sfile.close()
    dfile.close()

# this iterates and finds all the files and stores them into a single file 
# using dumping function
def combine_mk(source, dest) :

    #check if the source is a file
    if isfile(source):
        # if yes, then process the file 
        # if destination is not there , the function will create it, and if it is there, it will overrite it.
        dump_mk(source,dest)
    else:
        # so the source is a folder, 
        # now enumerate all the items in the source directory  
        # and take appropriate actions  
        for item in listdir(source):
            combine_mk(source+'/'+item,dest)

# %% [markdown]
# # Please Uncomment Below TWO Cells to Combine the Test & Train Data
# ## I did it thus I have left them commented
#
# If you need anyhelp Sritam, just whatsapp me ..

# %%
# used to combine all the processed files for both train & test data sets 
# together one to each other in their respective files

# Combine Test Data
s="processed_data/test_corpus"
d = "processed_data/test_combine.txt"
dfile = open(d,"w+", encoding="utf-8")
dfile.close()

combine_mk(s,d)

# %%
# Combine Train Data
s="processed_data/train_corpus"
d = "processed_data/train_combine.txt"
dfile = open(d,"w+", encoding="utf-8")
dfile.close()


combine_mk(s,d)

# %% [markdown]
# # Calculating Emission Probabilities
#
# I saw many videos on youtube with many examples, now I think this is first step we should do.
# And if we can do this nicely, this will give us COnfidence as well :)

# %% [markdown]
# ## What Does Emission Probability means?
# Make this thing clear, so that implementation is not wrong.
#
# Hidden states are tags
# And observations are words...
#
# So emission probability means, for word we calculate the chance that given tag, what is probability this word will occur
#
# Emission P of word w with tag t = Count of word_tag pairs with word = w and tag = t divided by count of word_tag pairs with tag equal to t no matter what word is....
#
# ### So far so good ...
#
# Obviously this makes things clear.
#
# I will make a dictionary counting appearnace of every tag , this will give me count of word_tag pairs with tag t for every tag t
#
# Or better make dictionary of dictionary
# Dict with keys as tags, and second dictionary with keys as words ? how's this ... seems fine right... this will give us all the data we need to go
#
# Finally to save it I will pickle the struct, and will see if I need to do anything else.

# %%
import pickle

# %%
# the emission probabilty calculator functtion

def emission_mk():
    # obviosly source file is 
    data = open("processed_data_sentence/train_sentence_combine_.txt", "r", encoding="utf-8")
    
    print("file successfully loaded")
    # make dictonary for tags as keys
    # this will have tag as keys and values as their count
    tag_dict = {}
    
    # make dictionary for tags and keys 
    # values will be another dictionary for words
    tag_dict_dict = {}
    
    # count number of sentences
    count = 0
    # now read every line one by one of this file
    for line in data :
        
        # if line is a new line then skip this line
        if len(line) < 2 :
            continue
            
        # split line into word_tag pairs with split
        pairs = line.split(" ")
        
        
        # iterate over pairs
        for pair in pairs :
            # split the give pair 
            try :
                [word,tag] = pair.split("_")
            except : 
                print(pair)
                continue
                    
            [word,tag] = pair.split("_")
            # increase frequency for this tag in tag dictinary
            tag_dict[tag] = tag_dict.get(tag,0) + 1
            
            # obtain the dictionary with given tag as key
            # in case the tag is not there, then the default value must be returned : empty dictionary
            temp_word_dict = tag_dict_dict.get(tag, {}) 
            # now increase the count in the word dictinary for corresponding word
            temp_word_dict[word] = temp_word_dict.get(word,0) + 1
            # now assign this dictionary to the system
            tag_dict_dict[tag] = temp_word_dict
            
            # all dictionaries filled properly
        # pairs in sentence processed
        count = count +1
        print("sentence number :", count, " processed")
    # all the lines are now processed
    
    # now all dictionaries are properly filled with values
    
    #pickle the first dictionary
    tag_dict_picklefile = open("pickle/tagscount","wb+")
    pickle.dump(tag_dict, tag_dict_picklefile)
    tag_dict_picklefile.close()
    
    # count emission probabilties
    # to do so we divide the word counts given tag with the count of the tag
    # iterate over all the tags in the system
    for tag in tag_dict :
        
        if tag_dict[tag] == 0:
            continue
        # for every word in the corresponding dictionary of the word
        for word in tag_dict_dict[tag]:
            tag_dict_dict[tag][word] = (1.0*tag_dict_dict[tag][word]) / tag_dict[tag]
        # all words for this tag settled
    # all tags settled
    
    #pickle the second dictionary
    emission_pickle = open ("pickle/emission", "wb+")
    pickle.dump(tag_dict_dict,emission_pickle)
    emission_pickle.close()
    
    # function complete

# %% [markdown]
# #  Please Uncomment Below Code to make the emission probability pickle object

# %%
# Run the above function for generating the files
emission_mk()

# %% [markdown]
# # Transission Probabilties
#
# what are they, first of all
#
# Basically they predict that after the apearance of certain tag t1 (say), what is the probability that next tag will be t2(saY).
#
#
# T2 may or may not be equal to T1.
#
# ## Next Obvious Question, How to get these values
#
# I think, I will iterate sentence wise, with each sentence begining with a special tag, called start, we will store the count of sentences (something around 4lac 32 thousands or 4lac 83 thousands. I don't remember exact values.
#
# I got this count during emission probabilty.
# Unfortunately I didnot saved this data.
#
# Never mind.
# Let's get back to task!
#
# So Transission P (t2) with t1 = Num of times t2 occurs after occurance of t1 / num of times t1 occurs in the data set. ....
#
# the denominator is simply the tag count pickle, which is to be unloaded. :)
#
# for numerator I need to store the number of times, t2 occurs after t1 .
#
# Example : Mohit (Noun) is(verb) a(adj) Boy(noun). So we will make a new tag, "START"
# New Sentence will be : ""(START) Mohit (Noun) is(verb) a(adj) Boy(noun).
#
# let's start

# %%
#function to find transmission probabilities
def transmission_mk():
    
    # open the file
    data = open("processed_data/train_combine.txt", "r", encoding="utf-8")
    print("file successfully loaded")
    
    # create dictionary for storing the tag pairs
    # structure tag_dict[t1][t2] = number of times t2 appears after the occurence of t1
    tag_dict = {}
    
    # counter 
    count = 0
    
    #iterate over every sentence in the train_combine.txt processed data file
    for line in data : 
        
        # strip end of line characters
        line = line.strip()
        
        # skip empty line
        if len(line) < 2 :
            continue
        
        # find pairs in the line
        pairs = line.split()
        
        # initialize the start tag value
        prev_tag = "START"
        
        
        # iterate over every pair
        for pair in pairs : 
            # split word tag pair
            try :
                [word,cur_tag] = pair.split("_")
            except : 
                print(pair)
                continue
                    
            [word,cur_tag] = pair.split("_")
            
            # obtain the dictionary for previous tag
            prev_tag_dict = tag_dict.get(prev_tag, {})
            
            # update the value of this tag, in the dictionary of previous tag
            prev_tag_dict[cur_tag] = prev_tag_dict.get(cur_tag,0)+1
            
            # updtate the complete main dictionary with new values
            tag_dict[prev_tag] = prev_tag_dict
            prev_tag=cur_tag
        # sentence iterated
        # increase count
        count = count +1
        
        # print statement for motivation purposes
        if count == 10000:
            print(count, " sentences processed")
    # whole file done
    print("total number of sentences in the text " , count)
    
    # now unpickle the tag file
    tags_count_file = open("pickle/tagscount","rb")
    tags_count_dict = pickle.load(tags_count_file)
    
    # for this run. add aditional value
    tags_count_dict["START"] = count
    
    # iterate over every tag in the list
    for t1 in tag_dict :
        
        # now for every tag in the sub dictionary updtae the value
        for t2 in tag_dict[t1] :
            # probability is equal to number of times t2 occurs after t1
            # divided by the number of times t1 occurs in the whole train data
            # we multiply by 1.0 to get a double value
            tag_dict[t1][t2] = (1.0*tag_dict[t1][t2])/ tags_count_dict[t1]
    
    # now pickle this dictionary
    transmission_pickle = open ("pickle/transmission", "wb+")
    pickle.dump(tag_dict,transmission_pickle)
    transmission_pickle.close()
    
    print("Function completed succesfully, all glories to HDGACBVSSP, pickle saved for transmission prob")

# %% [markdown]
# # Please UNcomment below block to generate transmission probabilities

# %%
# get transmission probabilities
transmission_mk()
import numpy as np

# %%
#viterbi algorithm implemention
#observed states are words
#hidden states are tags

def viterbi():
    
    file = open("processed_data_sentence/test_sentence_combine.txt", "r", encoding= "utf-8")
    
    pickled_emission=open("pickle/emission","rb")
    emission_dict=pickle.load(pickled_emission)
    pickled_emission.close()
    
    pickled_transition=open("pickle/transmission","rb")
    transition_dict=pickle.load(pickled_transition)
    pickled_transition.close()
    
    pickled_tags=open("pickle/tagscount","rb")
    tag_dict=pickle.load(pickled_tags)
    pickled_tags.close()
    
    tag_list=[*tag_dict]
    
    total_tag=tag_list
    predicted=0
    actual=0
    confusion_dict={}
    cnt=0
    for sentence in file:
        
        #initialising
        #extracting tag list

        #storing the the total probability
        final_value={}
        sentence=sentence.strip()
        if len(sentence) <2:
            continue
        pairs = sentence.split()
        wordlis = []
        taglis = []


        for pair in pairs :
            try :
                [word,trag] = pair.split("_")
            except :     
                print(pair)
                continue
            [word,tag] = pair.split("_")
            wordlis.append(word)
            taglis.append(tag)
            

        for tag in tag_list:
            
            a=emission_dict[tag].get(word,0.00000001)
            b=transition_dict["START"].get(tag,0.00000001)

            final_value[tag]=a*b
            
        
        final_value_tmp={}
        final_value_tmp=final_value
        result =[]
        for word in wordlis[1:]:
            
            final_value=final_value_tmp
            result.append(max(final_value, key=final_value.get))
            
            final_value_tmp={}
            
            for tag_cur in tag_list:
                tmp=[]
                for tag_prev in tag_list:
    #                 a=emission_dict[tag_cur].get(word,0.00000001)
    #                 b=transition_dict[tag_prev].get(tag_cur,0.00000001)

                    if word in emission_dict[tag_cur]:
                        a=emission_dict[tag_cur][word]
                    else:
                        a=0.00000001
                    if tag_prev in transition_dict and tag_cur in transition_dict[tag_prev]:
                        b=transition_dict[tag_prev][tag_cur]
                    else:
                        b=0.00000001

                    tmp.append(a*b*final_value[tag_prev])
                final_value_tmp[tag_cur]=max(tmp)
        result.append(max(final_value, key=final_value.get))
        
        cnt =cnt + 1
        if cnt%10000==0:
            print(cnt, " sentences processed")
            break
        
#         print(taglis)
#         print(result)
        actual +=len(result)
        predicted +=len(result)
        for i in range(len(result)):
            
            if taglis[i] not in total_tag:
                total_tag.append(taglis[i])
                
            tmp_dict=confusion_dict.get(taglis[i],{})
            tmp_dict[result[i]]=tmp_dict.get(result[i],0)+1
            confusion_dict[taglis[i]]=tmp_dict
            
            if taglis[i] != result[i]:
                predicted =predicted-1
                
    print(predicted/actual)
    
    mat=[[0 for i in range(len(total_tag))] for j in range(len(total_tag))]

    for i in range(len(total_tag)):
        for j in range(len(total_tag)):
            tmp_dict=confusion_dict.get(total_tag[i],{})
            mat[i][j]=tmp_dict.get(total_tag[j],mat[i][j])

        
    np.set_printoptions(threshold=np.inf ,linewidth=np.inf)
    # define data
    TAG = np.asarray(total_tag)
    # save to csv file
    np.savetxt('total_tags.csv', TAG.astype(str), fmt='%s', delimiter=',')

    np.set_printoptions(threshold=np.inf ,linewidth=np.inf)
    # define data
    data = np.asarray(mat)
    # save to csv file
    np.savetxt('confusion_matrix.csv', data.astype(int), fmt='%d', delimiter=',')

# %%
viterbi()
# Out:
# ['AT0', 'NN2']
# ['NN2', 'NN2']
# ['AV0', 'AT0', 'NN1', 'PRP', 'AT0', 'NN1', 'VHZ', 'DT0', 'NN1', 'PRF', 'NN1', 'NN1', 'PUN']
# ['PUN', 'AT0', 'NN1', 'PRP', 'AT0', 'NN1', 'VHZ', 'DT0', 'NN1', 'PRF', 'NN1', 'NN1', 'NN1']
# ['DT0', 'VHB', 'CRD', 'PUN', 'CRD', 'TO0', 'VVI', 'PRP', 'NN1', 'PRP', 'AT0', 'NN1', 'PUL', 'AV0', 'VVN', 'NN1', 'PUR', 'CJC', 'AT0', 'NN1', 'TO0', 'VVI', 'PRP-AVP', 'VVG', 'AV0', 'PUN']
# ['PUN', 'VHB', 'CRD', 'PUN', 'CRD', 'TO0', 'VVI', 'PRP', 'NN1', 'PRP', 'AT0', 'NN1', 'PUL', 'AV0', 'VVN', 'NN1', 'PUR', 'CJC', 'AT0', 'AJ0', 'TO0', 'VVI', 'PRP', 'VVG-NN1', 'AV0', 'AV0']
# ['EX0', 'VBB', 'AV0', 'AJ0', 'AJ0-NN1', 'NN2', 'PRP', 'DT0', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'VBB', 'AV0', 'AJ0', 'NN1', 'NN2', 'PRP', 'DT0', 'AJ0', 'NN1', 'NN1']
# ['AT0', 'AJ0-NN1', 'NN1', 'VBZ', 'CJT', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'POS', 'NN1', 'NN2', 'VBZ', 'PRP', 'AJ0', 'NN1', 'PRP', 'AT0', 'NN1', 'PRF', 'NN2', 'PNP', 'VVZ', 'PUN']
# ['PUN', 'AJ0', 'NN1', 'VBZ', 'CJT', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'POS', 'NN1', 'NN2', 'VBZ', 'PRP', 'AJ0', 'NN1', 'TO0', 'AT0', 'NN1', 'PRF', 'NN2', 'PNP', 'VVZ', 'VVZ']
# ['DT0', 'VBZ', 'CJS', 'DT0', 'NN1', 'VHZ', 'TO0', 'VVI', 'PRP', 'DPS', 'NN1', 'PRF', 'AT0', 'AJ0-NN1', 'NN1', 'NN1', 'CJC', 'PRP', 'AT0', 'NN1', 'VVZ', 'CJC', 'VVZ', 'DPS', 'NN2', 'TO0', 'VVI', 'PRP', 'AT0', 'NN2', 'PRF', 'DT0', 'PNQ', 'VVB', 'AT0', 'NN2', 'PUN']
# ['PUN', 'POS', 'AJ0-NN1', 'NN1', 'VBD', 'TO0', 'VVI', 'AJ0', 'AJ0-NN1', 'NN2', 'TO0', 'AV0', 'VVI', 'NP0', 'PRP', 'VVG', 'CRD', 'PRF', 'NN2', 'NN2']
# ['DT0', 'VVD', 'AT0', 'AJ0', 'NN1', 'CJS', 'AT0', 'NN1', 'VBD', 'AV0', 'AJ0', 'PUN']
# ['PUN', 'VVD', 'AT0', 'AJ0', 'NN1', 'CJS', 'AT0', 'NN1', 'VBD', 'AV0', 'AJ0', 'AJ0']
# ['DPS', 'ORD', 'AJ0', 'NN1', 'VVD', 'PRP', 'NN1', 'NN1', 'CRD', 'AVQ-CJS', 'CRD', 'AJ0', 'AJ0-NN1', 'NN2', 'VBD', 'VVN', 'PRP', 'CRD', 'PUN']
# ['PUN', 'ORD', 'AJ0', 'NN1', 'VVD', 'PRP', 'NN1', 'NN1', 'PNP', 'CJS', 'CRD', 'AJ0', 'AJ0-NN1', 'NN2', 'VBD', 'VVN', 'PRP', 'CRD', 'CRD']
# ['CJS-PRP', 'AT0', 'NN1', 'UNC', 'VVD', 'DPS', 'NN1', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'NN1', 'DTQ', 'AT0', 'NN1', 'VVN', 'VM0', 'AV0', 'VVI', 'AT0', 'NN1', 'PUN']
# ['PUN', 'AT0', 'NN1', 'UNC', 'VVD', 'DPS', 'NN1', 'TO0', 'AT0', 'AJ0', 'NN1', 'PRF', 'NN1', 'DTQ', 'AT0', 'NN1', 'VVD', 'VM0', 'AV0', 'VVI', 'AT0', 'NN1', 'NN1']
# ['DPS', 'AJS', 'NN2', 'VVD', 'PRP', 'NN1', 'NN1', 'CRD', 'AVQ-CJS', 'PNP', 'VVD', 'AT0', 'CRD', 'PRF', 'NP0', 'POS', 'NN2', 'VVN', 'PRP', 'NP0', 'PUN']
# ['PUN', 'AJS', 'NN2', 'VVD', 'PRP', 'NN1', 'NN1', 'CRD', 'AVQ', 'PNP', 'VVD', 'AT0', 'CRD', 'PRF', 'NP0', 'POS', 'NN2', 'VVD', 'TO0', 'NP0', 'NP0']
# ['DT0', 'VBD', 'XX0', 'AT0', 'AV0', 'AJ0', 'NN1', 'CJS', 'PNP', 'VBD', 'DT0', 'AV0', 'VVN', 'CJC', 'VVN', 'CJC', 'VVD', 'AVP', 'AV0', 'CJS', 'PNP', 'VVD', 'PRP-AVP', 'AT0', 'NN1', 'VVG', 'AJ0', 'CJC', 'AJ0', 'NN2', 'PRP', 'AJ0', 'NN2', 'PUN']
# ['PUN', 'VBD', 'XX0', 'AT0', 'AV0', 'AJ0', 'NN1', 'CJS', 'PNP', 'VBD', 'DT0', 'AV0', 'VVN', 'CJC', 'VVN', 'CJC', 'VVD', 'AVP', 'AV0', 'CJS', 'PNP', 'VVD', 'AVP', 'AT0', 'NN1', 'VVG', 'AJ0', 'CJC', 'AJ0', 'NN2', 'PRP', 'AJ0', 'NN2', 'NN2']
# ['DT0', 'PRF', 'DT0', 'NN2', 'AV0', 'VVN', 'TO0', 'VVI', 'PRP', 'UNC', 'PUN']
# ['PUN', 'PRF', 'DT0', 'NN2', 'AV0', 'VVN', 'TO0', 'VVI', 'PRP', 'UNC', 'UNC']
# ['AT0', 'NN1', 'VBD', 'TO0', 'VBI', 'VVN', 'PUN', 'CJS', 'EX0', 'VBD', 'AT0', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'NN1', 'VBD', 'TO0', 'VBI', 'VVN', 'PRP', 'AV0', 'EX0', 'VBD', 'AT0', 'AJ0', 'NN1', 'NN1']
# ['PRP', 'AT0', 'AJ0', 'NN1', 'NN1', 'PUN', 'AV0', 'VVN', 'PRP', 'AT0', 'NP0', 'NN1', 'PUN', 'DT0', 'VVN-VVD', 'NN2', 'VVD-VVN', 'AVP', 'PRP', 'NP0', 'AT0', 'AJ0', 'NN1', 'PRF', 'AJ0', 'NN1', 'VVD', 'PRP', 'AJ0', 'NN1', 'TO0', 'VVI', 'PNP', 'NN1', 'PUN', 'DTQ', 'AT0', 'NN2', 'AV0', 'VVD', 'PRP', 'NN1', 'PUN']
# ['PUN', 'AT0', 'AJ0', 'NN1', 'NN1', 'PUN', 'AV0', 'VVN', 'PRP', 'AT0', 'NP0', 'NN1', 'PUN', 'DT0', 'VVD', 'NN2', 'VVD', 'AVP', 'PRP', 'NP0', 'AT0', 'AJ0', 'NN1', 'PRF', 'AJ0', 'NN1', 'VVD', 'PRP', 'AJ0', 'NN1', 'TO0', 'VVI', 'PNP', 'NN1', 'PUN', 'DTQ', 'AT0', 'NN2', 'AV0', 'VVN', 'PRP', 'NN1', 'NN1']
# ['CJS', 'AT0', 'NN2', 'VBD', 'AV0', 'AV0', 'AV0', 'VVN', 'CJS', 'NN1', 'VM0', 'VHI', 'PNP', 'VVB', 'VBZ', 'AJ0', 'PRP', 'DT0', 'NN1', 'PUN']
# ['PUN', 'AT0', 'NN2', 'VBD', 'AV0', 'CJS', 'AV0', 'VVN', 'PRP', 'NN1', 'VM0', 'VHI', 'PNP', 'VVB', 'VBZ', 'AJ0', 'TO0', 'DT0', 'NN1', 'NN1']
# ['CJS', 'AT0', 'NN1', 'EX0', 'VHZ', 'VBN', 'AT0', 'AJ0', 'NN1', 'PRF', 'NN1', 'PRP', 'DT0', 'NN1', 'PRP', 'AT0', 'AJ0-NN1', 'NN1', 'PUN']
# ['PUN', 'AT0', 'NN1', 'EX0', 'VHZ', 'VBN', 'AT0', 'AJ0', 'NN1', 'PRF', 'NN1', 'PRP', 'DT0', 'NN1', 'PRP', 'AT0', 'AJ0', 'NN1', 'NN1']
# ['DT0', 'VM0', 'VBI', 'CJS', 'VVZ', 'TO0', 'VVI', 'PNP', 'VHB', 'VBN', 'VVN', 'CJC', 'CJS', 'DT0', 'AJ0', 'NN2', 'VVG', 'PRP', 'DPS', 'NN1', 'NN2', 'PRP', 'NP0', 'VBD', 'PRP', 'AT0', 'VVN', 'NN2', 'XX0', 'VVN', 'PRP', 'NP0', 'PRP', 'CRD', 'PUN']
# ['PUN', 'VM0', 'VBI', 'CJS', 'VVZ', 'TO0', 'VVI', 'PNP', 'VHB', 'VBN', 'VVN', 'CJC', 'CJS', 'DT0', 'AJ0', 'NN2', 'VVG', 'TO0', 'DPS', 'NN1', 'NN2', 'PRP', 'NP0', 'VBD', 'PRP', 'AT0', 'VVN', 'NN2', 'XX0', 'VVN', 'TO0', 'NP0', 'PRP', 'CRD', 'CRD']
# ['CJC', 'PNP', 'AV0', 'VDZ', 'XX0', 'VVI', 'DT0', 'AV0', 'PUN']
# ['PUN', 'PNP', 'AV0', 'VDZ', 'XX0', 'VVI', 'DT0', 'AV0', 'AV0']
# ['CJS', 'AT0', 'NN1', 'VVD', 'NP0', 'VVD', 'TO0', 'VVI', 'AV0', 'PRP', 'NN1', 'CJT', 'VVD', 'PRP', 'DPS', 'DT0', 'NN2', 'CJC', 'VBD', 'AJ0', 'TO0', 'VVI', 'PRP', 'PNP', 'PUN']
# ['PUN', 'AT0', 'NN1', 'VVD-VVN', 'NP0', 'VVD', 'TO0', 'VVI', 'AV0', 'TO0', 'NN1', 'CJT', 'VVD', 'PRP', 'DPS', 'DT0', 'NN2', 'CJC', 'VBD', 'AJ0', 'TO0', 'VVI', 'PRP', 'PNP', 'PNP']
# ['CJS-PRP', 'AT0', 'NN1', 'EX0', 'VBD', 'AT0', 'AJ0', 'NN1', 'PRF', 'NP0', 'POS', 'NN1', 'NN2', 'CJC', 'PRP', 'CRD', 'UNC', 'VVD', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'NN1', 'PUN']
# ['PUN', 'AT0', 'NN1', 'EX0', 'VBD', 'AT0', 'AJ0', 'NN1', 'PRF', 'NP0', 'POS', 'NN1', 'NN2', 'CJC', 'PRP', 'CRD', 'UNC', 'VVD', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'NN1', 'NN1']
# ['PNP', 'VVD', 'AVP', 'PRP', 'NP0', 'PRP', 'DPS', 'NN1', 'NN0', 'PRP', 'NP0', 'NN1', 'PRP', 'NP0', 'CJC', 'VVD', 'DPS', 'NN0', 'PRP', 'NP0', 'NN1', 'PRP', 'NP0', 'NP0', 'PUN']
# ['PUN', 'VVD', 'AVP', 'PRP', 'NP0', 'PRP', 'DPS', 'NN1', 'NN0', 'PRP', 'NP0', 'NP0', 'PRP', 'NP0', 'CJC', 'VVD', 'DPS', 'NN0', 'PRP', 'AT0', 'NN1', 'PRP', 'NP0', 'NP0', 'NP0']
# ['PRP', 'AT0', 'AJ0', 'UNC', 'UNC', 'VVD-VVN', 'AV0', 'PRP', 'DPS', 'AJ0-NN1', 'NN1', 'PUN', 'AV0', 'PRP', 'NP0', 'NP0', 'PUN']
# ['PUN', 'AT0', 'AJ0', 'NN1', 'UNC', 'VVD', 'AV0', 'TO0', 'DPS', 'AJ0-NN1', 'NN1', 'PUN', 'AV0', 'PRP', 'NP0', 'NP0', 'NP0']
# ['PNP', 'AV0', 'VHZ', 'DT0', 'NN1', 'DTQ', 'NN2-VVZ', 'ZZ0', 'NN1', 'PUL', 'NN1', 'PUR', 'PUN', 'CJC', 'AT0', 'NN1', 'NN1', 'CJT', 'VVZ', 'PRP', 'UNC', 'PUN']
# ['PUN', 'NP0', 'NP0', 'NP0', 'NP0', 'DT0', 'NN1', 'NN1', 'PUN', 'VVD', 'AVP', 'PRP', 'AT0', 'AJ0', 'NN1', 'NN1', 'PUN', 'NN1', 'PRF', 'NN1', 'CJC', 'NN1', 'VVZ', 'AT0', 'AJ0', 'NN1', 'PRP', 'AVQ', 'AT0', 'NN1', 'PRF', 'UNC', 'VBZ', 'VVN-AJ0', 'VVN-AJ0']
# ['PRP', 'DT0', 'NN1', 'AT0', 'NN1', 'VVZ', 'AJ0', 'NN1', 'PRP', 'CRD', 'AJ0', 'NN2', 'PUN']
# ['PUN', 'DT0', 'NN1', 'AT0', 'NN1', 'VVZ', 'AJ0', 'NN1', 'PRP', 'CRD', 'AJ0', 'NN2', 'NN2']
# ['ORD', 'PUN', 'CJS', 'UNC', 'VBZ', 'AV0', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'NN1', 'PNP', 'VM0', 'VBI', 'VVN', 'PNI', 'PRP', 'DPS', 'AJ0', 'NN2', 'PUN']
# ['PUN', 'PUN', 'CJS', 'UNC', 'VBZ', 'AV0', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'NN1', 'PNP', 'VM0', 'VBI', 'VVN', 'PNI', 'PRP', 'DPS', 'AJ0', 'NN2', 'NN2']
# ['ORD', 'PUN', 'UNC', 'AV0', 'VVZ', 'PNQ', 'CJC', 'DTQ', 'NN2', 'VBB', 'VVN', 'TO0', 'VBI', 'AJ0', 'PUN']
# ['PUN', 'PUN', 'UNC', 'AV0-AJ0', 'VVZ', 'PNQ', 'CJC', 'DTQ', 'NN2', 'VBB', 'VVN', 'TO0', 'VBI', 'AJ0', 'AJ0']
# ['CJC', 'ORD', 'PUN', 'NN2', 'VM0', 'XX0', 'VBI', 'VVN', 'DT0', 'AJ0', 'NN1', 'PRP', 'UNC', 'POS', 'NN1', 'PUN']
# ['PUN', 'ORD', 'NN1', 'NN2', 'VM0', 'XX0', 'VBI', 'VVN', 'DT0', 'AJ0', 'NN1', 'PRP', 'UNC', 'POS', 'NN1', 'NN1']
# ['AT0', 'AJ0', 'NN1', 'PRP', 'NP0', 'NP0', 'POS', 'NN1', 'VBZ', 'CJT-DT0', 'PUN', 'CJS', 'PNP', 'VBZ', 'AJ0', 'PRP', 'NN1', 'PUN', 'EX0', 'VBZ', 'AT0', 'AJ0', 'NN1', 'TO0', 'VVI', 'CJT', 'PNP', 'VBZ', 'VVN', 'AVP', 'PUN']
# ['PUN', 'AJ0', 'NN1', 'PRP', 'NP0', 'NP0', 'POS', 'NN1', 'VBZ', 'CJT', 'PNP', 'CJS', 'PNP', 'VBZ', 'AJ0', 'PRP', 'NN1', 'PUN', 'EX0', 'VBZ', 'AT0', 'AJ0', 'NN1', 'TO0', 'VVI', 'CJT', 'PNP', 'VBZ', 'VVN', 'AVP', 'AVP']
# ['DT0', 'NN2', 'PRF', 'UNC', 'PNQ', 'VHB', 'VVN', 'CJC', 'VVN', 'AV0', 'PRP', 'DPS', 'NN1', 'VVB', 'AV0', 'AV0', 'CJT', 'AT0', 'NN1', 'VBZ', 'AV0', 'CJC', 'AV0', 'VVN', 'PUN']
# ['AT0', 'AJ0', 'NN1', 'PRP', 'DT0', 'DT0', 'NN2', 'VBZ', 'CJT', 'PNP', 'VBD', 'XX0', 'VVN', 'PRP', 'UNC', 'PUN']
# ['PUN', 'AJ0', 'NN1', 'PRP', 'DT0', 'DT0', 'NN2', 'VBZ', 'CJT', 'PNP', 'VBD', 'XX0', 'VVN', 'PRP', 'UNC', 'UNC']
# ['AVQ', 'VBZ', 'UNC', 'AV0', 'AJ0', 'PRP', 'VVG-NN1', 'NN2', 'CJC', 'NN2', 'PUN']
# ['PNP', 'VBZ', 'UNC', 'AV0', 'AJ0', 'PRP', 'VVG', 'NN2', 'CJC', 'NN2', 'NN2']
# ['DT0', 'VVB', 'CJT', 'AT0', 'NN1', 'VBZ', 'CJT', 'UNC', 'VHZ', 'VBN', 'VVN', 'PRP', 'AJ0', 'NN1', 'AV0', 'AV0', 'CJT-DT0', 'AV0', 'DPS', 'DT0', 'NN1', 'AJ0', 'PUN', 'NP0', 'NP0', 'NP0', 'PUN', 'VBD', 'AT0', 'AJ0', 'NN1', 'CJC', 'AV0', 'AT0', 'NN1', 'VHZ', 'VBN', 'AJ0', 'PUN']
# ['PUN', 'VVB', 'CJT', 'AT0', 'NN1', 'VBZ', 'CJT', 'UNC', 'VHZ', 'VBN', 'VVN', 'PRP', 'AJ0', 'NN1', 'AV0', 'AV0', 'CJT', 'AV0', 'DPS', 'DT0', 'NN1', 'NP0', 'NP0', 'NP0', 'NP0', 'NP0', 'NP0', 'VBD', 'AT0', 'AJ0', 'NN1', 'CJC', 'AV0', 'AT0', 'NN1', 'VHZ', 'VBN', 'VVN', 'VVN']
# ['DT0', 'VVZ', 'NN1', 'PRP', 'CRD', 'NN2', 'PUN', 'ORD', 'PUN', 'EX0', 'VBZ', 'AT0', 'NN1', 'TO0', 'VVI', 'NP0', 'VBD', 'AT0', 'AJ0', 'NN1', 'PUN', 'CJC', 'ORD', 'PUN', 'AT0', 'NN2', 'VBD', 'AV0', 'VVN-VVD', 'CJT-DT0', 'VM0', 'VHI', 'VVN', 'AVP', 'DT0', 'PRF', 'DT0', 'NN2', 'PUN', 'PRP', 'AT0', 'NN1', 'CJT', 'PNP', 'DT0', 'VVD', 'NN1', 'NN2', 'CJT', 'VBD', 'AV0', 'AJ0', 'PUN', 'CJS', 'AT0', 'NN1', 'VVN-VVD', 'UNC', 'PUN']
# ['PUN', 'VVZ', 'NN1', 'PRP', 'CRD', 'NN2', 'PRP', 'ORD', 'NN1', 'EX0', 'VBZ', 'AT0', 'NN1', 'TO0', 'VVI', 'NP0', 'VBD', 'AT0', 'AJ0', 'NN1', 'PUN', 'CJC', 'ORD', 'NN1', 'AT0', 'NN2', 'VBD', 'AV0', 'VVN', 'CJT', 'VM0', 'VHI', 'VVN', 'AVP', 'DT0', 'PRF', 'DT0', 'NN2', 'PUN', 'PRP', 'AT0', 'NN1', 'CJT', 'PNP', 'DT0', 'VVN', 'NN1', 'NN2', 'CJT', 'VBD', 'AV0', 'AJ0', 'NN1', 'CJS', 'AT0', 'NN1', 'VVD', 'UNC', 'UNC']
# ['NN1-NP0', 'VBD', 'VVN', 'PRP', 'AT0', 'NN2', 'PRP', 'NP0', 'PRP', 'AT0', 'NN1-AJ0', 'CJC', 'VVD', 'PUN']
# ['PUN', 'VBD', 'VVN', 'PRP', 'AT0', 'NN2', 'PRP', 'NP0', 'CJS', 'AT0', 'AJ0', 'CJC', 'VVD', 'VVD']
# ['PNP', 'AV0', 'VVD', 'PRP', 'AT0', 'AJ0', 'NN1', 'VVN', 'PRP', 'AJ0', 'NN1', 'AV0', 'PRP', 'DPS', 'AJ0-NN1', 'NN1', 'PUN']
# ['PUN', 'AV0', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'VVN', 'PRP', 'AJ0', 'NN1', 'AV0', 'PRP', 'DPS', 'AJ0', 'NN1', 'NN1']
# ['NP0', 'VBD', 'VVN', 'PRP', 'AT0', 'NN1', 'PRP', 'NP0', 'AJ0', 'NN1', 'CJC', 'VVD', 'PUN', 'AV0', 'VVD-VVN', 'CRD', 'AJ0', 'NN1', 'NN2-VVZ', 'PUN']
# ['PUN', 'VBD', 'VVN', 'PRP', 'AT0', 'NN1', 'PRP', 'NP0', 'AJ0-NN1', 'NN1', 'CJC', 'VVD', 'PUN', 'AV0', 'VVN', 'CRD', 'AJ0', 'NN1', 'NN2-VVZ', 'NN2-VVZ']
# ['PNP', 'VVD', 'AVP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PRP', 'NP0', 'TO0', 'VVI', 'AT0', 'NN1', 'NN1', 'CJC', 'AT0', 'CRD', 'NN1', 'PNP', 'AJ0', 'PUN']
# ['PUN', 'VVD', 'AVP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PRP', 'NP0', 'TO0', 'VVI', 'AT0', 'NN1', 'NN1', 'CJC', 'AT0', 'CRD', 'VVD', 'PNP', 'AJ0', 'AJ0']
# ['NP0', 'POS', 'NN1', 'VVD', 'PNP', 'PRP', 'AJ0', 'NN1', 'PRP', 'VBG', 'AJ0', 'NN2', 'PRF', 'NN1', 'PUN']
# ['PUN', 'POS', 'NN1', 'VVD', 'PNP', 'TO0', 'AJ0', 'NN1', 'PRP', 'VBG', 'AJ0', 'NN2', 'PRF', 'NN1', 'NN1']
# ['VVD', 'DT0', 'NN1-VVB', 'PUN']
# ['PUN', 'DT0', 'NN1', 'NN1']
# ['NP0', 'VBD', 'AT0', 'AJ0', 'NN1', 'AV0', 'VVD', 'AJ0', 'PUN']
# ['PUN', 'VBD', 'AT0', 'AJ0', 'AJ0-NN1', 'AV0', 'VVD', 'AJ0', 'AJ0']
# ['AT0', 'NN1', 'PRP', 'UNC', 'POS', 'NN1', 'VBZ', 'CJT', 'PNP', 'VVZ', 'AV0', 'AV0', 'DT0', 'NN1', 'CJC', 'NN2', 'VVG', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'NN0', 'PNQ', 'PNP', 'VVZ', 'TO0', 'VBI', 'AJ0', 'PUN', 'CJS', 'AJ0', 'NN2', 'PRF', 'AT0', 'NN1', 'VBB', 'AJ0', 'TO0', 'VVI', 'AVP', 'VVG', 'AJ0', 'PRP', 'NN2', 'PUN']
# ['PUN', 'CJC', 'AJ0', 'NN1', 'AV0', 'AJ0', 'NN1', 'AV0', 'CJC', 'NN1-VVB', 'PRP', 'AV0', 'DT0', 'NN2', 'CJT', 'PNP', 'VHB', 'PNI', 'NN1', 'CJT', 'VDZ', 'PNI', 'AV0', 'AV0']
# ['VVG-NN1', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'AT0', 'CRD', 'NN1', 'PUN', 'PNP', 'VBZ', 'AJ0', 'CJT', 'NN2', 'VBB', 'TO0', 'VBI', 'VVN', 'AV0', 'AT0', 'NN1', 'UNC', 'VVZ', 'PNP', 'VVB', 'PUN']
# ['PUN', 'TO0', 'AT0', 'AJ0', 'NN1', 'PRF', 'AT0', 'CRD', 'NN1', 'PUN', 'PNP', 'VBZ', 'AJ0', 'CJT', 'NN2', 'VBB', 'TO0', 'VBI', 'VVN', 'AV0', 'AT0', 'NN1', 'UNC', 'VVZ', 'PNP', 'VVB', 'VVB']
# ['PRP', 'AJ0', 'NN2', 'PUN', 'CJS', 'AT0', 'NN1', 'VDZ', 'XX0', 'VVI', 'AT0', 'AJ0-NN1', 'NN1', 'TO0', 'VVI', 'UNC', 'PRP', 'AT0', 'AJ0', 'NN1', 'CJC', 'NN1', 'AV0', 'UNC', 'VM0', 'XX0', 'VVI', 'DT0', 'NN1', 'PRP', 'DPS', 'DT0', 'PUN']
# ['PUN', 'AJ0', 'NN2', 'PUN', 'CJS', 'AT0', 'NN1', 'VDZ', 'XX0', 'VVI', 'AT0', 'NN1', 'NN1', 'TO0', 'VVI', 'UNC', 'PRP', 'AT0', 'AJ0', 'NN1', 'CJC', 'NN1', 'AV0', 'UNC', 'VM0', 'XX0', 'VVI', 'DT0', 'NN1', 'PRP', 'DPS', 'DT0', 'DT0']
# ['DT0', 'VVZ', 'UNC', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'VBG', 'AJ0', 'PRP', 'CJC', 'VHG', 'TO0', 'VVI', 'PNI', 'PNP', 'VDZ', 'CJC', 'VBZ', 'VVN-AJ0', 'TO0', 'VHI', 'VDN', 'PUN']
# ['PUN', 'VVZ', 'UNC', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'VBG', 'AJ0', 'TO0', 'CJC', 'VHG', 'TO0', 'VVI', 'PNI', 'PNP', 'VDZ', 'CJC', 'VBZ', 'VVN-AJ0', 'TO0', 'VHI', 'VDN', 'VDN']
# ['CJS', 'UNC', 'VHD', 'VVN', 'AT0', 'CRD', 'NP0', 'NP0', 'NN2', 'AV0', 'EX0', 'VM0', 'VHI', 'VBN', 'DT0', 'NN1-VVB', 'PRP', 'NN1', 'PRP', 'DPS', 'NN2', 'PRP', 'AT0', 'AJ0', 'CRD', 'NN2', 'PUN']
# ['PUN', 'AT0', 'NN1', 'PRP', 'NP0', 'CRD', 'AT0', 'NN1', 'VBD', 'VVN', 'TO0', 'VVI', 'AT0', 'NN1', 'NN1', 'NP0', 'TO0', 'VVI', 'AT0', 'NP0', 'NP0', 'NN2', 'CJC', 'AV0', 'VVI', 'UNC', 'POS', 'NN1', 'PUN', 'VVG', 'AJ0', 'NN2', 'PRP', 'AJ0', 'NN1', 'NN1']
# ['PRP', 'AT0', 'NN2', 'VBZ', 'PNI', 'VVG', 'UNC', 'TO0', 'VVI', 'AT0', 'NN1', 'NN1', 'POS', 'NN1', 'CJS', 'NN2', 'VBB', 'VVN-AJ0', 'PUN']
# ['PUN', 'AT0', 'NN2', 'VBZ', 'PNI', 'VVG', 'UNC', 'PRP', 'VVI', 'AT0', 'NN1', 'NN1', 'POS', 'NN1', 'PRP', 'NN2', 'VBB', 'VVN', 'VVN']
# ['CJS', 'VBZ', 'VVN', 'AV0', 'PRP', 'AT0', 'NN1', 'PUN', 'PRP', 'AT0', 'AJ0-NN1', 'NN2', 'PRP', 'DTQ', 'AT0', 'NN1-NP0', 'VBD', 'VVN', 'PRP', 'NN1', 'PNP', 'VBZ', 'AT0', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'VBZ', 'VVN', 'AV0', 'PRP', 'AT0', 'NN1', 'PUN', 'PRP', 'AT0', 'AJ0', 'NN2', 'PRP', 'DTQ', 'AT0', 'NN1', 'VBD', 'VVN', 'TO0', 'NN1', 'PNP', 'VBZ', 'AT0', 'AJ0', 'NN1', 'NN1']
# ['UNC', 'VM0', 'VVI', 'AV0', 'AJ0', 'CJS', 'PNP', 'AV0', 'VHZ', 'VBN', 'CJC', 'CJS', 'PNP', 'AV0', 'VVD-VVN', 'AT0', 'CRD', 'NN1', 'PRP', 'AV0', 'CRD', 'NN2', 'PRP', 'AV0', 'VBG', 'AV0', 'VVN', 'TO0', 'VVI', 'AV0', 'VBZ', 'AT0', 'NN1', 'TO0', 'VVI', 'CJT-DT0', 'UNC', 'VM0', 'VBI', 'DT0', 'DT0', 'NN1-AJ0', 'AV0', 'PUN']
# ['PUN', 'VM0', 'VVI', 'CJS', 'AJ0', 'CJS', 'PNP', 'AV0', 'VHZ', 'VBN', 'CJC', 'CJS', 'PNP', 'AV0', 'VVN', 'AT0', 'CRD', 'NN1', 'PRP', 'AV0', 'CRD', 'NN2', 'PRP', 'AV0', 'VBG', 'AV0', 'VVN', 'TO0', 'VVI', 'EX0', 'VBZ', 'AT0', 'NN1', 'TO0', 'VVI', 'CJT', 'UNC', 'VM0', 'VBI', 'DT0', 'DT0', 'AJ0', 'AV0', 'AV0']
# ['UNC', 'PUN', 'AT0', 'AJ0-NN1', 'NN1', 'NN1', 'PUL', 'NN1', 'PUR', 'PUN', 'VVD', 'NN1', 'PRP', 'CRD', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'AJ0', 'NN1', 'PUN', 'DTQ', 'VHD', 'VBN', 'VVG', 'PRP-AVP', 'AJ0', 'NN2', 'PRP', 'AV0', 'CRD', 'NN2', 'PUN']
# ['UNC', 'VBD', 'AV0', 'AJ0', 'PRP', 'NP0', 'POS', 'NN1', 'TO0', 'VVI', 'AJ0', 'NN2', 'NN1', 'PUL', 'NP0', 'PUR', 'PUN', 'DTQ', 'PNP', 'VVD', 'CJS-PRP', 'VVG', 'PRP', 'DPS', 'AJ0', 'NN2', 'PUN']
# ['PUN', 'VBD', 'AV0', 'AJ0', 'PRP', 'NP0', 'POS', 'NN1', 'TO0', 'VVI', 'AJ0', 'NN2', 'NN1', 'PUL', 'NP0', 'PUR', 'PUN', 'DTQ', 'PNP', 'VVD', 'PRP', 'VVG', 'PRP', 'DPS', 'AJ0', 'NN2', 'NN2']
# ['CJC', 'PRP', 'AT0', 'NN1', 'PUN']
# ['PUN', 'TO0', 'AT0', 'NN1', 'NN1']
# ['NP0', 'VVD', 'NN1', 'PRF', 'AT0', 'AJ0', 'NN1', 'CJC', 'VHD', 'DT0', 'NN1-VVB', 'PRP', 'UNC', 'PUN']
# ['PUN', 'VVD', 'NN1', 'PRF', 'AT0', 'AJ0', 'NN1', 'CJC', 'VHD', 'DT0', 'NN1', 'PRP', 'UNC', 'UNC']
# ['UNC', 'VVD-VVN', 'DPS', 'NN1', 'PRP', 'AJ0-NN1', 'CJC', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'VDD', 'DT0', 'PNP', 'VM0', 'TO0', 'VVI', 'AT0', 'NN1', 'PRF', 'NP0', 'PUN']
# ['PUN', 'VVD', 'DPS', 'NN1', 'PRP', 'AT0', 'CJC', 'PRP', 'AT0', 'NN1', 'PRF', 'AT0', 'NN1', 'VDD', 'DT0', 'PNP', 'VM0', 'TO0', 'VVI', 'AT0', 'NN1', 'PRF', 'NP0', 'NP0']
# ['PRP', 'CRD', 'NN1', 'PNP', 'VVD', 'AT0', 'AJ0', 'NN1', 'PRF', 'DPS', 'DT0', 'PRP', 'NP0', 'PNQ', 'VVD', 'DT0', 'CRD', 'AJ0', 'CJC', 'AJ0', 'NN2', 'PRP', 'AT0', 'NN2', 'PUN']
# ['PUN', 'CRD', 'NN1', 'PNP', 'VVD', 'AT0', 'AJ0', 'NN1', 'PRF', 'DPS', 'DT0', 'PRP', 'NP0', 'PNQ', 'VVD', 'DT0', 'CRD', 'AJ0', 'CJC', 'AJ0', 'NN2', 'TO0', 'AT0', 'NN2', 'NN2']
# ['UNC', 'POS', 'NN1', 'NN1', 'AV0', 'VVD', 'PRP', 'AT0', 'NN1', 'CJT', 'DT0', 'PRF', 'DPS', 'AJ0', 'NN2', 'VBD', 'AJ0', 'NN2', 'PUN', 'CJS', 'PRP', 'UNC', 'PUN', 'PNP', 'VVD', 'DT0', 'AJ0', 'NN1', 'PRP', 'AT0', 'NN1', 'PUN']
# ['PUN', 'POS', 'NN1', 'NN1', 'AV0', 'VVN', 'PRP', 'AT0', 'NN1', 'CJT', 'DT0', 'PRF', 'DPS', 'AJ0', 'NN2', 'VBD', 'AJ0', 'NN2', 'PUN', 'CJS', 'PRP', 'UNC', 'UNC', 'PNP', 'VVD', 'DT0', 'AJ0', 'NN1', 'PRP', 'AT0', 'NN1', 'NN1']
# ['UNC', 'VVZ', 'PRP', 'DT0', 'NN1', 'AT0', 'AJ0', 'NN1', 'CJT-DT0', 'VDZ', 'XX0', 'AV0', 'VVI', 'PRP', 'AT0', 'NN1', 'CJT', 'PRP', 'AJ0', 'NN2', 'EX0', 'VHB', 'VBN', 'AJ0', 'NN2', 'VVN', 'PRP', 'DPS', 'NN2', 'PUN']
# ['PUN', 'VVZ', 'TO0', 'DT0', 'NN1', 'AT0', 'AJ0', 'NN1', 'CJT', 'VDZ', 'XX0', 'AV0', 'VVB', 'PRP', 'AT0', 'NN1', 'CJT', 'PRP', 'AJ0', 'NN2', 'EX0', 'VHB', 'VBN', 'AJ0', 'NN2', 'VVN', 'PRP', 'DPS', 'NN2', 'NN2']
# ['EX0', 'VBZ', 'AT0', 'AJ0', 'NN1', 'PRP', 'AT0', 'AJ0', 'NN1', 'CJT', 'CJS', 'PNP', 'VDZ', 'XX0', 'VVI', 'PRP', 'AT0', 'NN1', 'PRF', 'UNC', 'PUN', 'AJ0', 'NN2', 'VM0', 'VVI', 'NP0', 'VDZ', 'XX0', 'VVI', 'PRP', 'PNP', 'PUN']
# ['PUN', 'VBZ', 'AT0', 'AJ0', 'NN1', 'PRP', 'AT0', 'AJ0', 'NN1', 'CJT', 'CJS', 'PNP', 'VDZ', 'XX0', 'VVI', 'TO0', 'AT0', 'NN1', 'PRF', 'UNC', 'UNC', 'AJ0', 'NN2', 'VM0', 'VVI', 'NP0', 'VDZ', 'XX0', 'VVI', 'PRP', 'PNP', 'PNP']
# ['PRP', 'AT0', 'NN1', 'PRP', 'NP0', 'PRP', 'CRD', 'NP0', 'NP0', 'NP0', 'PUN', 'AV0', 'AT0', 'NN1', 'NN1', 'PUN', 'VVD', 'PNP', 'VM0', 'XX0', 'VVI', 'AT0', 'NN1', 'PRF', 'UNC', 'PUN']
# ['PUN', 'AT0', 'NN1', 'PRP', 'NP0', 'PRP', 'CRD', 'NP0', 'NP0', 'NP0', 'NP0', 'AV0', 'AT0', 'NN1', 'NN1', 'PUN', 'VVD', 'PNP', 'VM0', 'XX0', 'VVI', 'AT0', 'NN1', 'PRF', 'UNC', 'UNC']
# ['VHD', 'NP0', 'VVN', 'TO0', 'VVI', 'PRP', 'AT0', 'NN1', 'POS', 'DT0', 'AJ0', 'NN1', 'NN1', 'PUL', 'AT0', 'NN1', 'NN2', 'NN1', 'PUR', 'PUN', 'PNP', 'VM0', 'VHI', 'VVN', 'CJT', 'UNC', 'VBZ', 'VVN', 'PRP', 'CRD', 'NN2', 'PUN']
# ['PUN', 'NP0', 'VVD', 'TO0', 'VVI', 'PRP', 'AT0', 'NN1', 'POS', 'DT0', 'AJ0', 'NN1', 'NN1', 'PUL', 'AT0', 'NN1', 'NN2', 'NN1', 'PUR', 'PUN', 'PNP', 'VM0', 'VHI', 'VVN', 'CJT', 'UNC', 'VBZ', 'VVN', 'PRP', 'CRD', 'NN2', 'NN2']
# ['CJS', 'AT0', 'NN1', 'NN1', 'VBZ', 'VVN', 'PRP', 'DT0', 'NN1', 'NN2', 'PRP', 'AT0', 'NN1', 'PNI-CRD', 'VM0', 'VVI', 'CJT', 'AT0', 'NN2', 'VHB', 'VVN', 'TO0', 'VVI', 'AT0', 'NN1', 'PUN']
# ['PUN', 'AT0', 'NN1', 'NN1', 'VBZ', 'VVN', 'TO0', 'DT0', 'NN1', 'NN2', 'PRP', 'AT0', 'NN1', 'CRD', 'VM0', 'VVI', 'CJT', 'AT0', 'NN2', 'VHB', 'VVN', 'TO0', 'VVI', 'AT0', 'NN1', 'NN1']
# ['AV0', 'CRD', 'NN0', 'VVB-NN1', 'PRP', 'UNC', 'PRP', 'DPS', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'CRD', 'NN0', 'NN1-VVB', 'PRP', 'UNC', 'PRP', 'DPS', 'AJ0', 'NN1', 'NN1']
# ['PRP', 'CRD', 'AT0', 'NN1', 'PRF', 'UNC', 'PUN', 'VVN', 'PRP', 'PUQ', 'ZZ0', 'PUQ', 'PUN', 'VBD', 'NP0', 'NP0', 'NP0', 'PUN']
# ['PUN', 'CRD', 'AT0', 'NN1', 'PRF', 'UNC', 'UNC', 'VVN', 'PRP', 'AT0', 'NP0', 'NP0', 'NP0', 'VBD', 'NP0', 'NP0', 'NP0', 'NP0']
# ['AJ0', 'NN2', 'PRP', 'UNC', 'VBB', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'VVD-VVN', 'NP0', 'NP0', 'NP0', 'NP0', 'PUN']
# ['PUN', 'NN2', 'TO0', 'UNC', 'VBB', 'VVN', 'TO0', 'AT0', 'AJ0', 'NN1', 'VVN', 'NP0', 'NP0', 'NP0', 'NP0', 'NP0']
# ['UNC', 'VVZ', 'PRP', 'UNC', 'PRP', 'AT0', 'NN1', 'NN1', 'PRP', 'NP0', 'PUN']
# ['PUN', 'NN1', 'PRP', 'UNC', 'PRP', 'AT0', 'NN1', 'NN1', 'PRP', 'NP0', 'NP0']
# ['UNC', 'VBZ', 'AV0', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'CJC', 'AT0', 'AJ0', 'NN1', 'AV0', 'VVZ', 'PRP', 'DT0', 'AV0', 'CJC', 'VVZ', 'DT0', 'NN2', 'PRP', 'AVQ', 'UNC', 'VVZ', 'PRP-AVP', 'DPS', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'VBZ', 'AV0', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'CJC', 'AT0', 'AJ0', 'NN1', 'AV0', 'VVZ', 'TO0', 'DT0', 'AV0', 'CJC', 'VVZ', 'DT0', 'NN2', 'PRP', 'AVQ', 'UNC', 'VVZ', 'PRP', 'DPS', 'AJ0', 'NN1', 'NN1']
# ['UNC', 'VBZ', 'AJ0', 'TO0', 'VVI', 'AV0', 'PRP', 'NP0', 'CJS', 'PNP', 'VDZ', 'AV0', 'VVI', 'AJ0', 'PRP', 'NN2', 'PRP', 'NP0', 'AT0', 'NP0-NN1', 'NN1', 'PRF', 'CRD', 'PUL', 'VVB', 'NN1', 'CRD', 'PUR', 'PUN', 'DTQ', 'VBD', 'VVN', 'PRP', 'NN1', 'PRP', 'NN1', 'PUN']
# ['PUN', 'VBZ', 'AJ0', 'TO0', 'VVI', 'AV0', 'PRP', 'NP0', 'CJS', 'PNP', 'VDZ', 'AV0', 'VVI', 'AJ0', 'PRP', 'NN2', 'PRP', 'NP0', 'AT0', 'NN1', 'NN1', 'PRF', 'CRD', 'PUL', 'VVB', 'NN1', 'CRD', 'PUR', 'PUN', 'DTQ', 'VBD', 'VVN', 'PRP', 'NN1', 'TO0', 'VVI', 'VVI']
# ['DT0', 'NN2', 'AV0', 'UNC', 'VVD', 'VVN', 'PRP', 'AT0', 'NP0', 'PRP', 'NP0', 'NP0', 'PUN', 'AV0', 'PRP', 'AT0', 'NN1', 'PRF', 'UNC', 'PUN']
# ['PUN', 'NN2', 'AV0', 'UNC', 'VVD', 'AJ0', 'PRP', 'AT0', 'NP0', 'PRP', 'NP0', 'NP0', 'NP0', 'DT0', 'TO0', 'AT0', 'NN1', 'PRF', 'UNC', 'UNC']
# ['AT0', 'NN1', 'PRF', 'AT0', 'CRD', 'NN1', 'NN2', 'PUN', 'NN1', 'NN1', 'PUN', 'AT0', 'AJ0', 'NP0', 'NP0', 'POS', 'AJ0', 'NN1', 'PUN', 'CJC', 'AJ0', 'AJ0', 'NN2', 'AV0', 'VHG', 'AT0', 'NN1', 'PRP', 'AT0', 'DT0', 'NN1', 'VBD', 'PUN', 'XX0', 'AV0', 'PUN', 'AT0', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'NN1', 'PRF', 'AT0', 'CRD', 'NN1', 'NN2', 'PUN', 'NN1', 'NN1', 'PUN', 'AT0', 'AJ0', 'NP0', 'NP0', 'POS', 'AJ0', 'NN1', 'PUN', 'CJC', 'AJ0', 'AJ0', 'NN1', 'DT0', 'VHG', 'AT0', 'NN1', 'PRP', 'AT0', 'DT0', 'NN1', 'VBD', 'PUN', 'XX0', 'AV0', 'PUN', 'AT0', 'AJ0', 'NN1', 'NN1']
# ['PNP', 'VBZ', 'AJ0', 'TO0', 'VVI', 'AVQ', 'AJ0', 'UNC', 'VBZ', 'AV0', 'CJS', 'PRP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PNP', 'VBD', 'VVN', 'PUN', 'TO0', 'VVI', 'PNP', 'PRF', 'AT0', 'AJ0', 'NN1', 'PRF', 'AT0', 'NP0', 'NP0', 'PRP', 'CRD', 'PUN', 'PNP', 'AV0', 'VVD', 'AV0', 'CJC', 'AT0', 'AJ0', 'NN1', 'AV0', 'VVN', 'UNC', 'POS', 'NN1', 'PRP', 'AT0', 'NN1', 'PRP', 'AT0', 'NN1', 'CJT', 'VVD', 'PNP', 'VBG', 'VVN', 'AV0', 'PUN']
# ['PUN', 'VBZ', 'AJ0', 'TO0', 'VVI', 'AVQ', 'AJ0', 'UNC', 'VBZ', 'AV0', 'CJS', 'PRP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PNP', 'VBD', 'VVN', 'PRP', 'PRP', 'VVI', 'PNP', 'PRF', 'AT0', 'AJ0', 'NN1', 'PRF', 'AT0', 'NP0', 'NP0', 'PRP', 'CRD', 'PUN', 'PNP', 'AV0', 'VVN', 'AV0', 'CJC', 'AT0', 'AJ0', 'NN1', 'AV0', 'VVN', 'UNC', 'POS', 'NN1', 'TO0', 'AT0', 'NN1', 'PRP', 'AT0', 'NN1', 'CJT', 'VVD', 'PNP', 'VBG', 'VVN', 'AV0', 'AV0']
# ['CJS', 'AT0', 'AJ0', 'NN1', 'VM0', 'XX0', 'VVI', 'PRP', 'UNC', 'PNQ', 'VBB', 'NP0', 'POS', 'NN2', 'PUN', 'AT0', 'NN1', 'PRF', 'UNC', 'VBZ', 'PRP', 'NN1', 'PRF', 'VBG', 'VVN', 'PRP', 'AJ0', 'NN1', 'PUN', 'VVG', 'PRP', 'NN1', 'AT0', 'AJ0', 'NN1', 'PRF', 'VHG', 'DT0', 'AT0', 'NN1', 'PRP', 'AT0', 'ORD', 'NN1', 'PUN']
# ['PUN', 'AT0', 'AJ0', 'NN1', 'VM0', 'XX0', 'VVI', 'PRP', 'UNC', 'PNQ', 'VBB', 'NP0', 'POS', 'NN2', 'PUN', 'AT0', 'NN1', 'PRF', 'UNC', 'VBZ', 'PRP', 'NN1', 'PRF', 'VBG', 'VVN', 'PRP', 'AJ0', 'NN1', 'PUN', 'VVG', 'PRP', 'NN1', 'AT0', 'AJ0', 'NN1', 'PRF', 'VHG', 'DT0', 'AT0', 'NN1', 'PRP', 'AT0', 'ORD', 'NN1', 'NN1']
# ['NN1', 'NN2', 'PRP', 'UNC', 'VVB-NN1', 'AVP', 'AJ0', 'NN2', 'PRP', 'AT0', 'NN1', 'TO0', 'VVI', 'NP0', 'NP0', 'PRF', 'NP0', 'PUN', 'CJC', 'VVG', 'NN1', 'NN2', 'PRP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PRP', 'NP0', 'PUN']
# ['PUN', 'NN2', 'PRP', 'UNC', 'NN1', 'AVP', 'AJ0', 'NN2', 'PRP', 'AT0', 'NN1', 'TO0', 'VVI', 'NP0', 'NP0', 'PRF', 'NP0', 'NP0', 'CJC', 'VVG', 'NN1', 'NN2', 'PRP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PRP', 'NP0', 'NP0']
# ['DT0', 'PRF', 'DPS', 'NN1', 'VBZ', 'AV0', 'VVN', 'VVG', 'AJ0', 'NN2', 'PRP', 'AJ0', 'AJ0', 'AJ0', 'NN0', 'PUN']
# ['PUN', 'PRF', 'DPS', 'NN1', 'VBZ', 'AV0', 'VVN', 'VVG', 'AJ0', 'NN2', 'PRP', 'AJ0', 'AJ0', 'AJ0', 'NN0', 'NN0']
# ['PRP', 'DT0', 'NN1', 'UNC', 'VHZ', 'VHN', 'AT0', 'NN1', 'PRF', 'NN2', 'CJS', 'PNP', 'VBZ', 'AJ0', 'TO0', 'VVI', 'AVQ', 'AJ0', 'NN2', 'AV0', 'VBB', 'PUL', 'VVB', 'NN1', 'CRD', 'PUR', 'PUN']
# ['PUN', 'DT0', 'NN1', 'UNC', 'VHZ', 'VHN', 'AT0', 'NN1', 'PRF', 'NN2', 'CJS', 'PNP', 'VBZ', 'AJ0', 'TO0', 'VVI', 'AVQ', 'AJ0', 'NN2', 'AV0', 'VBB', 'PUL', 'VVI', 'NN1', 'CRD', 'PUR', 'PUR']
# ['UNC', 'VVZ', 'AJ0', 'NN1', 'PRF', 'NN2', 'PUN', 'NN2', 'PUN', 'PNQ', 'VM0', 'AV0', 'VVI', 'AJ0', 'NN2', 'PRF', 'AT0', 'NN1', 'PRP', 'VVG-AJ0', 'NN1', 'PUN', 'CJC', 'AT0', 'AJ0-NN1', 'NN1', 'PRF', 'AT0', 'NN1', 'DT0', 'NN0', 'VM0', 'VVI', 'VBZ', 'AV0', 'AJ0', 'PUN']
# ['PUN', 'VVZ', 'AJ0', 'NN1', 'PRF', 'AT0', 'NN1', 'NN2', 'PUN', 'PNQ', 'VM0', 'AV0', 'VVI', 'AJ0', 'NN2', 'PRF', 'AT0', 'NN1', 'PRP', 'VVG', 'NN1', 'PUN', 'CJC', 'AT0', 'AJ0-NN1', 'NN1', 'PRF', 'AT0', 'NN1', 'DT0', 'NN0', 'VM0', 'VVI', 'VBZ', 'AV0', 'AJ0', 'AJ0']
# ['PRP', 'AT0', 'AJ0', 'NN1', 'NN1', 'VHZ', 'VVN', 'DT0', 'PRF', 'UNC', 'VBZ', 'AJ0', 'NN1', 'PRF', 'NN1', 'CJS', 'AJ0', 'NN2', 'VVB', 'PNP', 'AJ0', 'PRP', 'AJ0', 'NN2', 'TO0', 'VVI', 'AJ0-NN1', 'PRP', 'AV0', 'AV0-AJ0', 'AV0', 'PRP', 'AT0', 'NN1', 'NN1', 'PUN']
# ['PUN', 'AT0', 'AJ0', 'NN1', 'NN1', 'VHZ', 'VVN', 'AV0', 'PRF', 'UNC', 'POS', 'AJ0', 'NN1', 'PRF', 'NN1', 'CJS', 'AJ0', 'NN2', 'VVB', 'PNP', 'AJ0', 'PRP', 'AJ0', 'NN2', 'TO0', 'VVI', 'AJ0', 'PRP', 'AV0', 'AJ0', 'AV0', 'PRP', 'AT0', 'NN1', 'NN1', 'NN1']
# ['CJS', 'EX0', 'VM0', 'AV0', 'VBI', 'AT0', 'NN1', 'PRP', 'AJ0', 'NN1', 'PUL', 'NP0', 'PUR', 'PUN', 'AJ0', 'NN1', 'VVZ', 'CJT', 'UNC', 'VBZ', 'AJ0', 'TO0', 'VVI', 'PNI', 'CJT', 'AV0', 'VVZ', 'DPS', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'EX0', 'VM0', 'AV0', 'VBI', 'AT0', 'NN1', 'PRP', 'AJ0', 'NN1', 'PUL', 'AT0', 'NN1', 'PUN', 'PRP', 'NN1', 'VVZ', 'CJT', 'UNC', 'VBZ', 'AJ0', 'TO0', 'VVI', 'PNI', 'CJT', 'AV0', 'VVZ', 'DPS', 'AJ0', 'NN1', 'NN1']
# ['NP0', 'POS', 'ORD', 'NN1', 'NN1', 'VBZ', 'AT0', 'NN1', 'NN2', 'NN0', 'PUL', 'NP0', 'PUR', 'PUN', 'VVN-VVD', 'PRP', 'NP0', 'PRP', 'NP0', 'CJC', 'VVG', 'DT0', 'CRD', 'NN0', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'AV0', 'NN0', 'CRD', 'AT0', 'NN1', 'PUN']
# ['PUN', 'POS', 'ORD', 'NN1', 'NN1', 'VBZ', 'AT0', 'NN1', 'NN2', 'NN0', 'PUL', 'NP0', 'PUR', 'PUN', 'VVN', 'PRP', 'NP0', 'PRP', 'NP0', 'CJC', 'VVG', 'DT0', 'CRD', 'NN0', 'PRP', 'AT0', 'AJ0', 'NN1', 'PRF', 'AV0', 'NN0', 'CRD', 'AT0', 'NN1', 'NN1']
# ['PNP', 'VBZ', 'NN1', 'PRF', 'UNC', 'CJC', 'AV0', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'VBZ', 'NN1', 'PRF', 'UNC', 'CJC', 'AV0', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'NN1']
# ['PRP', 'UNC', 'PUN', 'PRP', 'DT0', 'NN2', 'NP0', 'VDD', 'XX0', 'AV0', 'VVI', 'PRP', 'AT0', 'NN1', 'CJT', 'PNP', 'VBD', 'VVN', 'PRP', 'DT0', 'NN2', 'PUN']
# ['PUN', 'UNC', 'UNC', 'PRP', 'DT0', 'NN2', 'NP0', 'VDD', 'XX0', 'AV0', 'VVB', 'PRP', 'AT0', 'NN1', 'CJT', 'PNP', 'VBD', 'VVN', 'PRP', 'DT0', 'NN1', 'NN1']
# ['NP0', 'VVD', 'PRP', 'CRD', 'PRP', 'AT0', 'NN1', 'NN1', 'CJC', 'NP0', 'NN1', 'PUL', 'NP0', 'PUR', 'PUN', 'VVG', 'AVP', 'AT0', 'DT0', 'AJ0', 'NN2', 'PRF', 'AT0', 'NN1', 'CJC', 'AJ0', 'NN2', 'PRF', 'NN2', 'PNQ', 'VHD', 'VVN', 'PRP', 'NP0', 'PRP', 'NN1', 'NN1', 'NP0', 'AT0', 'AV0', 'AJ0', 'NN1', 'VBD', 'VVN', 'PUN', 'VVG', 'PRP-AVP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PRP', 'UNC', 'POS', 'NN2', 'PRP', 'CRD', 'NP0-NN1', 'PUN', 'PRP', 'NP0', 'PUN']
# ['PUN', 'VVD', 'PRP', 'CRD', 'CJS', 'AT0', 'NN1', 'NN1', 'CJC', 'AT0', 'NN1', 'PUL', 'AT0', 'NN1', 'PUN', 'VVG', 'AVP', 'AT0', 'DT0', 'AJ0', 'NN2', 'PRF', 'AT0', 'NN1', 'CJC', 'AJ0', 'NN2', 'PRF', 'AT0', 'PNQ', 'VHD', 'VVN', 'PRP', 'NP0', 'PRP', 'NN1', 'NN1', 'NP0', 'AT0', 'AV0', 'AJ0', 'NN1', 'VBD', 'VVN', 'PRP', 'VVG', 'PRP', 'AT0', 'AJ0', 'AJ0', 'NN1', 'PRP', 'UNC', 'POS', 'NN2', 'PRP', 'CRD', 'NP0-NN1', 'PUN', 'PRP', 'NP0', 'NP0']
# ['AT0', 'AJ0-NN1', 'NN1', 'PRF', 'NP0', 'VBD', 'PUN', 'PUQ', 'TO0', 'VVI', 'AT0', 'NN1', 'PRF', 'NN2', 'CJC', 'NN2', 'VVN', 'PRP', 'DT0', 'NN1', 'NN2', 'CJC', 'TO0', 'VVI', 'PRP-AVP', 'DPS', 'NN1', 'PUN', 'PUQ']
# ['PUQ', 'AJ0-NN1', 'NN1', 'PRF', 'AT0', 'VBD', 'VVN', 'PRP', 'TO0', 'VVI', 'AT0', 'NN1', 'PRF', 'NN2', 'CJC', 'NN2-VVZ', 'VM0', 'PRP', 'DT0', 'NN1', 'NN2', 'CJC', 'TO0', 'VVI', 'PRP', 'DPS', 'NN1', 'PUN', 'PUN']
# ['AT0', 'AJ0', 'NN1', 'PRF', 'NP0', 'VBD', 'PUN', 'PUQ', 'TO0', 'VVI', 'AT0', 'NN2', 'PRF', 'NN1', 'NN1', 'VVN', 'PRP', 'AJ0', 'NN2', 'PUN', 'PUQ']
# ['PUQ', 'AJ0', 'NN1', 'PRF', 'AT0', 'VBD', 'VVN', 'PRP', 'TO0', 'VVI', 'AT0', 'NN2', 'PRF', 'NN1', 'NN1', 'VM0', 'PRP', 'AJ0', 'NN2', 'PUN', 'PUN']
# ['CJS', 'DT0', 'NN1', 'VVD', 'AJ0', 'CJC', 'AT0', 'NN1', 'PRF', 'NN2', 'VM0', 'VBI', 'AJ0', 'NP0', 'VVD', 'TO0', 'VVI', 'DT0', 'AT0', 'AV0', 'AJ0', 'NN2', 'PRF', 'NP0', 'POS', 'NN2', 'CJC', 'NN2', 'AV0', 'PRP', 'AT0', 'AJ0', 'NN2', 'PUN']
# ['PUN', 'AV0', 'NN1', 'VVD', 'AJ0', 'CJC', 'AT0', 'NN1', 'PRF', 'AT0', 'VM0', 'VBI', 'VVN', 'PRP', 'VVD', 'TO0', 'VVI', 'DT0', 'AT0', 'AV0', 'AJ0', 'NN2', 'PRF', 'NP0', 'POS', 'NN2', 'CJC', 'NN2', 'AV0', 'PRP', 'AT0', 'AJ0', 'NN2', 'NN2']
# ['AV0', 'PUN', 'PNP', 'VVD', 'DT0', 'NN1-VVB', 'NN1', 'VVG', 'CJC', 'VVG', 'NP0', 'PUN']
# ['PUN', 'PUN', 'PNP', 'VVD', 'DT0', 'NN1', 'NN1', 'VVG', 'CJC', 'VVG', 'NP0', 'NP0']
# ['DT0', 'VBD', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'PUN']
# ['PUN', 'VBD', 'VVN', 'PRP', 'AT0', 'AJ0', 'NN1', 'NN1']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-e051e07ec6dc> in <module>
# ----> 1 viterbi()
#
# <ipython-input-46-8bf7b8e44595> in viterbi()
#      80                     else:
#      81                         a=0.00000001
# ---> 82                     if tag_prev in transition_dict and tag_cur in transition_dict[tag_prev]:
#      83                         b=transition_dict[tag_prev][tag_cur]
#      84                     else:
#
# KeyboardInterrupt:

# %%
#confusion matrix
